# %%
import os 
import pandas as pd
from pathlib import Path
from tqdm.notebook import tqdm

sectors = ['agriculture', 'apparel', 'chemicals', 'machinery', 'materials', 
           'metals', 'miscellaneous', 'transport', 'minerals']

new_sectors = ['Agriculture', 'Apparel', 'Chemicals', 'Machinery', 'Materials', 
           'Metals', 'Miscellaneous', 'Transport', 'Minerals']
rename_columns = {s: ns for s, ns in zip(sectors, new_sectors)}
sectors = new_sectors

region2agg_dict = {
    'east africa': 'Africa', 
    'central africa': 'Africa',
    'north africa': 'Africa',
    'southern africa': 'Africa',
    'west africa': 'Africa',
    'caribbean': 'America',
    'central america': 'America',
    'south america': 'America',
    'north america': 'America',
    'central asia': 'Asia',
    'east asia': 'Asia',
    'south asia': 'Asia',
    'southeast asia': 'Asia',
    'west asia': 'Asia',
    'eastern europe': 'Europe', 
    'nordic': 'Europe',
    'southern europe': 'Europe',
    'western europe': 'Europe',
    'australia and new zealand': 'Oceania',
    'melanesia': 'Oceania',
    'micronesia': 'Oceania',
    'polynesia': 'Oceania',
}


project_dir = Path('C:\shares_TARIFF_project\comtrade_new\DID_country')


volume_df = pd.read_csv(project_dir / '2015_2021.csv', header=0)
volume_df = volume_df.rename(columns=rename_columns)
volume_df.head()
# Out:
#         source  year  month  Agriculture   Apparel  Chemicals  Machinery  \
# 0  Afghanistan  2015      1     807693.0  508764.0        NaN    45445.0
# 1  Afghanistan  2015      2     564296.0  170889.0        NaN    47867.0
# 2  Afghanistan  2015      3     153039.0  731135.0        NaN     5582.0
# 3  Afghanistan  2015      4     384263.0  281741.0        NaN    26328.0
# 4  Afghanistan  2015      5      57945.0  240599.0        NaN    10655.0
#
#    Materials     Metals  Minerals  Miscellaneous  Transport
# 0        NaN     4956.0       NaN       269303.0    20858.0
# 1        NaN  4838991.0       NaN       403538.0        NaN
# 2        NaN   146989.0       NaN       279085.0        NaN
# 3     2856.0   474628.0       NaN      1070675.0     4451.0
# 4    24119.0  1664127.0       NaN       676760.0     3607.0

# %%
# find the top 20 countries
volume_df['sum'] = volume_df.apply(lambda x: sum([x[i] for i in sectors]), axis=1)
top_countries = volume_df.groupby(by=['source'])[['sum']] \
                .sum().sort_values(by = ['sum'], ascending = False) \
                .head(22).index.tolist()

#print(volume_df)
volume_df = volume_df.query('source in @top_countries')


# 更新下国家或地区的名称，去掉空格（空格在did运算中会出路径问题）
volume_df['source'] = volume_df['source'].apply(lambda x: str(x).replace(' ', '_'))
top_countries = volume_df['source'].unique()
print(top_countries)
# Out:
# ['Brazil' 'Canada' 'China' 'France' 'Germany' 'India' 'Indonesia'
#  'Ireland' 'Israel' 'Italy' 'Japan' 'Malaysia' 'Mexico' 'Netherlands'
#  'Other_Asia,_nes' 'Rep._of_Korea' 'Russian_Federation' 'Singapore'
#  'Switzerland' 'Thailand' 'United_Kingdom' 'Viet_Nam']

# %%
region_df = pd.read_csv(project_dir / 'countries2regions_new.csv', header=0)
country2region_dict = {c:r for c, r in zip(region_df['source_country'], region_df['source_region'])}

region_df['agg'] = region_df['source_region'].map(region2agg_dict)

region2countries_dict = {}
for region, group_df in region_df.groupby(by=['agg']):
    region2countries_dict[region] = group_df['source_country'].tolist()

# 区分 USA和 Rest of America(ROA)

China_list = ['China']
region2countries_dict['China'] = China_list
roa_list = []
for c in region2countries_dict.get('Asia'):
    if c not in China_list:
        roa_list.append(c)
region2countries_dict['ROA'] = roa_list
del region2countries_dict['Asia']
# Out:
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2890156325.py:7: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for region, group_df in region_df.groupby(by=['agg']):

# %% [markdown]
# # get panel data - trade war

# %%
country2region_dict = {}
for rg, ct_list in region2countries_dict.items():
    for ct in ct_list:
        country2region_dict[ct] = rg



volume_sum_df = volume_df.groupby(by=['source', 'year', 'month']).sum()
volume_sum_df['region'], volume_sum_df['year'], volume_sum_df['month'] = zip(*volume_sum_df.index)
volume_sum_df.reset_index(drop=True, inplace=True)

# volume_mean_df = volume_sum_df.groupby(by=['year', 'month']).mean()
# volume_mean_df['year'], volume_mean_df['month'] = zip(*volume_mean_df.index)
# volume_mean_df.reset_index(drop=True, inplace=True)



# volume => percentage 转化为占比
years = volume_sum_df['year'].unique()
months = volume_sum_df['month'].unique()
for y in years:
    for m in months:
        query_df = volume_sum_df.query('year == @y and month == @m')[sectors]
        #print(query_df)
        _sum = query_df.sum()
        secter2sum_dict = {s:v for s, v in zip(_sum.index, _sum.tolist())}
        for idx in query_df.index:
            for s, v in secter2sum_dict.items():
                _v = volume_sum_df.loc[idx, s]
                p = _v / v * 100
                volume_sum_df.loc[idx, s] = p

print(volume_sum_df)
# Out:
#       Agriculture    Apparel  Chemicals  Machinery  Materials    Metals  \
# 0        4.260698   0.449057   0.975222   0.402846   2.959273  4.610218
# 1        4.212676   0.396849   1.083890   0.349177   2.800043  3.163597
# 2        4.211868   0.353062   0.720292   0.330025   2.819042  2.520451
# 3        3.811707   0.542173   0.834325   0.378019   3.039443  2.548202
# 4        3.735771   0.434122   0.792456   0.355908   3.262317  2.435849
# ...           ...        ...        ...        ...        ...       ...
# 1830     4.629573  21.344427   0.388025   5.234711   3.430279  1.663261
# 1831     3.857840  16.901892   0.363505   5.145161   3.246773  1.759954
# 1832     3.330712  16.311611   0.426333   6.408609   3.102815  1.842076
# 1833     2.767803  14.883711   0.381127   6.995031   3.014355  2.217961
# 1834     3.957236  17.472758   0.378028   6.319674   3.502277  2.408479
#
#       Minerals  Miscellaneous  Transport           sum    region  year  month
# 0     3.451515       1.987340   0.839547  2.551333e+09    Brazil  2015      1
# 1     3.467143       1.692296   1.236381  2.108391e+09    Brazil  2015      2
# 2     2.748739       1.906381   1.192158  2.282777e+09    Brazil  2015      3
# 3     4.822988       2.107802   1.089009  2.393643e+09    Brazil  2015      4
# 4     3.111920       1.843103   1.014062  2.180285e+09    Brazil  2015      5
# ...        ...            ...        ...           ...       ...   ...    ...
# 1830  0.134183       8.282140   0.374414  1.004290e+10  Viet_Nam  2021      8
# 1831  0.115866       5.536925   0.358781  8.897176e+09  Viet_Nam  2021      9
# 1832  0.112434       4.218933   0.439960  9.757611e+09  Viet_Nam  2021     10
# 1833  0.036846       3.748645   0.317745  9.899949e+09  Viet_Nam  2021     11
# 1834  0.029890       5.128549   0.319289  1.015861e+10  Viet_Nam  2021     12
#
# [1835 rows x 13 columns]

# %%
# empty dir
panel_dir = project_dir / 'panels-trade-war'
for fp in panel_dir.rglob('*.csv'):
    os.remove(fp)

# %%
exp_years = [2018,2019]
com_years = [2015,2016,2017]



def get_did_panel(volume_sum_df, exp_years, com_years, sector, region):
    # volume_sum_df 中除去region外的求平均
    volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
    volume_mean_df['year'], volume_mean_df['month'] = zip(*volume_mean_df.index)
    volume_mean_df.reset_index(drop=True, inplace=True)
    com_df = volume_mean_df.query('year < 2020')[['year', 'month', sector]]
    com_df['name'] = 'mean'
    com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
    com_df.loc[com_df.query('year in @exp_years').index, 'time'] = 1
    com_df['time'] = com_df['time'].astype('int')
    com_df.loc[:, 'group'] = 0
    print(volume_mean_df)


    exp_df = volume_sum_df.query('year < 2020 and region == @region')[['region', 'year', 'month', sector]]
    exp_df = exp_df.rename(columns={'region': 'name'})
    exp_df.loc[exp_df.query('year in @com_years').index, 'time'] = 0
    exp_df.loc[exp_df.query('year in @exp_years').index, 'time'] = 1
    exp_df['time'] = exp_df['time'].astype('int')
    exp_df.loc[:, 'group'] = 1


    concat_df = pd.concat([exp_df, com_df])
    concat_df['did'] = concat_df.apply(lambda x: x['time'] * x['group'], axis=1)
    concat_df['date'] = concat_df.apply(lambda x: '{}-{}'.format(x['year'], x['month']), axis=1)
    del concat_df['year'], concat_df['month']
    concat_df = concat_df.rename(columns={sector: 'value'})
    # concat_df['value'] = np.log(concat_df['value'] + 1)
    return concat_df

for region in top_countries:
    for sector in sectors:
        panel_df = get_did_panel(volume_sum_df, exp_years, com_years, sector, region)
        panel_df.to_csv(panel_dir / f'{region}-{sector}.csv', header=True, index=False)
# Out:
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.559014  4.740521   4.715466   4.742722   4.620987  4.542371
# 1      4.561301  4.743007   4.710291   4.745277   4.628569  4.611257
# 2      4.561340  4.745092   4.727605   4.746189   4.627665  4.641883
# 3      5.062542  5.234622   5.219246   5.243262   5.103187  5.129042
# 4      4.584011  4.741232   4.724169   4.744957   4.606556  4.645912
# ..          ...       ...        ...        ...        ...       ...
# 79     4.600226  4.743070   4.729583   4.743963   4.596065  4.614879
# 80     4.581353  4.745898   4.726317   4.740987   4.592440  4.598820
# 81     4.557084  4.746480   4.723012   4.740128   4.600889  4.656413
# 82     4.557989  4.741563   4.718304   4.744750   4.590495  4.673229
# 83     4.549179  4.741892   4.712522   4.741257   4.591383  4.650291
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.597547       4.667270   4.721926  7.362274e+09  2015      1
# 1   4.596803       4.681319   4.703029  6.667146e+09  2015      2
# 2   4.631012       4.671125   4.705135  8.180585e+09  2015      3
# 3   5.009316       5.152221   5.205842  8.402794e+09  2015      4
# 4   4.613718       4.674138   4.713616  7.680181e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.615565       4.713684   4.729098  1.032878e+10  2021      8
# 80  4.505935       4.722000   4.712585  1.030837e+10  2021      9
# 81  4.574118       4.710694   4.717817  1.056350e+10  2021     10
# 82  4.622877       4.713919   4.720952  1.091290e+10  2021     11
# 83  4.645317       4.715325   4.698235  1.083811e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      3.660803  4.680379   4.148595   4.546881   3.488935  3.946910
# 1      3.585739  4.662675   4.180786   4.517309   3.399899  3.875454
# 2      3.636015  4.672263   4.168223   4.543787   3.541681  3.928924
# 3      3.936417  5.143235   4.711509   5.023590   3.833489  4.220738
# 4      3.663419  4.662248   4.193140   4.556486   3.574887  3.952095
# ..          ...       ...        ...        ...        ...       ...
# 79     3.509258  4.701255   4.373152   4.577587   3.631457  3.815235
# 80     3.527123  4.696685   4.378062   4.580126   3.637227  3.811812
# 81     3.573620  4.698622   4.326327   4.581423   3.597362  3.751924
# 82     3.640962  4.688724   4.336359   4.584107   3.594375  3.862138
# 83     3.770605  4.698981   4.332081   4.586344   3.675591  3.878917
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   1.716544       4.203283   3.696468  6.248113e+09  2015      1
# 1   1.566861       4.139412   3.840765  5.632463e+09  2015      2
# 2   1.777159       4.182948   3.795554  7.034949e+09  2015      3
# 3   1.993056       4.528472   4.246315  7.207489e+09  2015      4
# 4   1.865488       4.134381   3.769023  6.612449e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  1.755998       4.338568   4.046015  8.961516e+09  2021      8
# 80  1.898014       4.353906   4.018440  9.028366e+09  2021      9
# 81  1.839772       4.305933   3.979286  9.199316e+09  2021     10
# 82  1.500723       4.306278   3.963007  9.420613e+09  2021     11
# 83  1.313986       4.280916   3.975282  9.382109e+09  2021     12
#
# [84 rows x 12 columns]
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.333527  2.021010   4.317343   2.978264   3.390206  3.869607
# 1      4.368900  2.096792   4.358952   3.179664   3.493363  3.830288
# 2      4.396994  2.176607   4.264151   3.073718   3.432199  3.755720
# 3      4.916801  2.484570   4.806518   3.431453   3.911826  4.167547
# 4      4.417250  2.150993   4.293114   3.042922   3.382297  3.782357
# ..          ...       ...        ...        ...        ...       ...
# 79     4.550544  2.521320   4.401956   3.444174   3.577201  3.958920
# 80     4.539316  2.339812   4.380910   3.274305   3.537336  3.939036
# 81     4.548757  2.458319   4.325878   3.307069   3.529942  3.959266
# 82     4.555550  2.500488   4.317039   3.256844   3.605926  4.005111
# 83     4.498311  2.602813   4.121825   3.225187   3.541225  3.909769
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.705296       3.023109   4.491390  5.588358e+09  2015      1
# 1   4.731881       3.110307   4.544175  5.211756e+09  2015      2
# 2   4.716941       3.101055   4.506418  6.241592e+09  2015      3
# 3   5.230788       3.579357   4.989418  6.559046e+09  2015      4
# 4   4.711737       2.981914   4.490109  5.831584e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.749023       2.971252   4.403515  8.260081e+09  2021      8
# 80  4.735270       2.965930   4.413275  8.041469e+09  2021      9
# 81  4.749789       2.943940   4.414946  8.245745e+09  2021     10
# 82  4.745567       3.030616   4.446346  8.573763e+09  2021     11
# 83  4.743117       3.060719   4.478542  8.456665e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.333527  2.021010   4.317343   2.978264   3.390206  3.869607
# 1      4.368900  2.096792   4.358952   3.179664   3.493363  3.830288
# 2      4.396994  2.176607   4.264151   3.073718   3.432199  3.755720
# 3      4.916801  2.484570   4.806518   3.431453   3.911826  4.167547
# 4      4.417250  2.150993   4.293114   3.042922   3.382297  3.782357
# ..          ...       ...        ...        ...        ...       ...
# 79     4.550544  2.521320   4.401956   3.444174   3.577201  3.958920
# 80     4.539316  2.339812   4.380910   3.274305   3.537336  3.939036
# 81     4.548757  2.458319   4.325878   3.307069   3.529942  3.959266
# 82     4.555550  2.500488   4.317039   3.256844   3.605926  4.005111
# 83     4.498311  2.602813   4.121825   3.225187   3.541225  3.909769
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.705296       3.023109   4.491390  5.588358e+09  2015      1
# 1   4.731881       3.110307   4.544175  5.211756e+09  2015      2
# 2   4.716941       3.101055   4.506418  6.241592e+09  2015      3
# 3   5.230788       3.579357   4.989418  6.559046e+09  2015      4
# 4   4.711737       2.981914   4.490109  5.831584e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.749023       2.971252   4.403515  8.260081e+09  2021      8
# 80  4.735270       2.965930   4.413275  8.041469e+09  2021      9
# 81  4.749789       2.943940   4.414946  8.245745e+09  2021     10
# 82  4.745567       3.030616   4.446346  8.573763e+09  2021     11
# 83  4.743117       3.060719   4.478542  8.456665e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.333527  2.021010   4.317343   2.978264   3.390206  3.869607
# 1      4.368900  2.096792   4.358952   3.179664   3.493363  3.830288
# 2      4.396994  2.176607   4.264151   3.073718   3.432199  3.755720
# 3      4.916801  2.484570   4.806518   3.431453   3.911826  4.167547
# 4      4.417250  2.150993   4.293114   3.042922   3.382297  3.782357
# ..          ...       ...        ...        ...        ...       ...
# 79     4.550544  2.521320   4.401956   3.444174   3.577201  3.958920
# 80     4.539316  2.339812   4.380910   3.274305   3.537336  3.939036
# 81     4.548757  2.458319   4.325878   3.307069   3.529942  3.959266
# 82     4.555550  2.500488   4.317039   3.256844   3.605926  4.005111
# 83     4.498311  2.602813   4.121825   3.225187   3.541225  3.909769
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.705296       3.023109   4.491390  5.588358e+09  2015      1
# 1   4.731881       3.110307   4.544175  5.211756e+09  2015      2
# 2   4.716941       3.101055   4.506418  6.241592e+09  2015      3
# 3   5.230788       3.579357   4.989418  6.559046e+09  2015      4
# 4   4.711737       2.981914   4.490109  5.831584e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.749023       2.971252   4.403515  8.260081e+09  2021      8
# 80  4.735270       2.965930   4.413275  8.041469e+09  2021      9
# 81  4.749789       2.943940   4.414946  8.245745e+09  2021     10
# 82  4.745567       3.030616   4.446346  8.573763e+09  2021     11
# 83  4.743117       3.060719   4.478542  8.456665e+09  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.333527  2.021010   4.317343   2.978264   3.390206  3.869607
# 1      4.368900  2.096792   4.358952   3.179664   3.493363  3.830288
# 2      4.396994  2.176607   4.264151   3.073718   3.432199  3.755720
# 3      4.916801  2.484570   4.806518   3.431453   3.911826  4.167547
# 4      4.417250  2.150993   4.293114   3.042922   3.382297  3.782357
# ..          ...       ...        ...        ...        ...       ...
# 79     4.550544  2.521320   4.401956   3.444174   3.577201  3.958920
# 80     4.539316  2.339812   4.380910   3.274305   3.537336  3.939036
# 81     4.548757  2.458319   4.325878   3.307069   3.529942  3.959266
# 82     4.555550  2.500488   4.317039   3.256844   3.605926  4.005111
# 83     4.498311  2.602813   4.121825   3.225187   3.541225  3.909769
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.705296       3.023109   4.491390  5.588358e+09  2015      1
# 1   4.731881       3.110307   4.544175  5.211756e+09  2015      2
# 2   4.716941       3.101055   4.506418  6.241592e+09  2015      3
# 3   5.230788       3.579357   4.989418  6.559046e+09  2015      4
# 4   4.711737       2.981914   4.490109  5.831584e+09  2015      5
# ...
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
#     Agriculture   Apparel  Chemicals  Machinery  Materials    Metals  \
# 0      4.602587  4.174772   4.756380   4.698168   4.730539  4.736067
# 1      4.639490  4.178541   4.757352   4.698049   4.730047  4.736725
# 2      4.618873  4.125869   4.754631   4.687136   4.723476  4.739293
# 3      5.079778  4.437907   5.257060   5.181953   5.217979  5.225495
# 4      4.571403  4.136053   4.755316   4.680918   4.722794  4.736255
# ..          ...       ...        ...        ...        ...       ...
# 79     4.541449  3.745503   4.743427   4.512633   4.598558  4.682702
# 80     4.578198  3.957053   4.744595   4.516897   4.607297  4.678097
# 81     4.603299  3.985161   4.741603   4.456733   4.614152  4.674187
# 82     4.630105  4.053157   4.743756   4.428808   4.618364  4.656288
# 83     4.573465  3.929869   4.743903   4.460968   4.595130  4.647215
#
#     Minerals  Miscellaneous  Transport           sum  year  month
# 0   4.761472       4.628010   4.756778  7.349464e+09  2015      1
# 1   4.757212       4.645868   4.757999  6.651424e+09  2015      2
# 2   4.753688       4.625884   4.755569  8.128818e+09  2015      3
# 3   5.255282       5.107569   5.258204  8.363504e+09  2015      4
# 4   4.759186       4.614539   4.757033  7.628223e+09  2015      5
# ..       ...            ...        ...           ...   ...    ...
# 79  4.755515       4.367517   4.744076  9.991124e+09  2021      8
# 80  4.756387       4.498242   4.744820  1.004922e+10  2021      9
# 81  4.756551       4.561003   4.740954  1.024934e+10  2021     10
# 82  4.760150       4.583398   4.746774  1.058507e+10  2021     11
# 83  4.760481       4.517688   4.746701  1.050680e+10  2021     12
#
# [84 rows x 12 columns]
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\965263728.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()

# %% [markdown]
# # DID-trade-war

# %%
import re
import ipystata

region_list = list(top_countries)
sector_list = sectors

# empty dir
panel_dir = project_dir / 'temp'
for fp in panel_dir.rglob('*.txt'):
    os.remove(fp)

# %%
# %%stata -i sector_list -i region_list
# foreach region in `region_list' {
#     display "------------------------`region'---------------------------------"
#     clear
#     cd "C:\shares_TARIFF_project\comtrade_new\DID_country"
#     foreach sector in `sector_list' {
#         import delimited "./panels-trade-war/`region'-`sector'.csv"
#         egen time1 = group(date)
#         xtset time1 group
#         reghdfe value did, absorb(time1 group)
#         outreg2 using "./temp/tradewar-`region'-`sector'.txt"
#         clear
#     }
# }
# Out:
# ------------------------Brazil---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       5.06
#                                                   Prob > F        =     0.0283
#                                                   R-squared       =     0.7174
#                                                   Adj R-squared   =     0.4203
#                                                   Within R-sq.    =     0.0802
#                                                   Root MSE        =     0.4603
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.3857282   .1715319    -2.25   0.028    -.7290865   -.0423698
#        _cons |   4.291835   .0542431    79.12   0.000     4.183255    4.400414
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       4.77
#                                                   Prob > F        =     0.0330
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9986
#                                                   Within R-sq.    =     0.0760
#                                                   Root MSE        =     0.0816
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0664119   .0304022    -2.18   0.033    -.1272685   -.0055554
#        _cons |   2.595274    .009614   269.95   0.000     2.576029    2.614518
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.07
#                                                   Prob > F        =     0.7970
#                                                   R-squared       =     0.9972
#                                                   Adj R-squared   =     0.9942
#                                                   Within R-sq.    =     0.0012
#                                                   Root MSE        =     0.1460
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0140646   .0544157    -0.26   0.797    -.1229895    .0948602
#        _cons |   2.852718   .0172078   165.78   0.000     2.818273    2.887163
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.99
#                                                   Prob > F        =     0.3229
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9986
#                                                   Within R-sq.    =     0.0168
#                                                   Root MSE        =     0.0836
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0310467   .0311427     1.00   0.323    -.0312922    .0933856
#        _cons |   2.566787   .0098482   260.64   0.000     2.547073      2.5865
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.67
#                                                   Prob > F        =     0.4172
#                                                   R-squared       =     0.9462
#                                                   Adj R-squared   =     0.8896
#                                                   Within R-sq.    =     0.0114
#                                                   Root MSE        =     0.2524
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0768624   .0940675     0.82   0.417    -.1114341    .2651589
#        _cons |   3.913685   .0297467   131.57   0.000     3.854141     3.97323
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.24
#                                                   Prob > F        =     0.6247
#                                                   R-squared       =     0.8709
#                                                   Adj R-squared   =     0.7351
#                                                   Within R-sq.    =     0.0042
#                                                   Root MSE        =     0.5342
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0979206   .1990937     0.49   0.625    -.3006087    .4964499
#        _cons |   3.742826   .0629589    59.45   0.000       3.6168    3.868853
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       7.43
#                                                   Prob > F        =     0.0085
#                                                   R-squared       =     0.9807
#                                                   Adj R-squared   =     0.9604
#                                                   Within R-sq.    =     0.1135
#                                                   Root MSE        =     0.2847
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2891467     .10611    -2.72   0.008    -.5015489   -.0767446
#        _cons |   3.373811   .0335549   100.55   0.000     3.306643    3.440978
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       3.74
#                                                   Prob > F        =     0.0579
#                                                   R-squared       =     0.9906
#                                                   Adj R-squared   =     0.9807
#                                                   Within R-sq.    =     0.0606
#                                                   Root MSE        =     0.2543
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1833772   .0947799    -1.93   0.058    -.3730997    .0063453
#        _cons |    2.97833    .029972    99.37   0.000     2.918334    3.038326
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.11
#                                                   Prob > F        =     0.7437
#                                                   R-squared       =     0.5302
#                                                   Adj R-squared   =     0.0361
#                                                   Within R-sq.    =     0.0019
#                                                   Root MSE        =     0.8325
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1019331   .3102622    -0.33   0.744    -.7229903    .5191242
#        _cons |   4.323513   .0981135    44.07   0.000     4.127117    4.519908
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------Canada---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       8.25
#                                                   Prob > F        =     0.0057
#                                                   R-squared       =     0.9910
#                                                   Adj R-squared   =     0.9815
#                                                   Within R-sq.    =     0.1246
#                                                   Root MSE        =     1.3943
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.492934   .5196169    -2.87   0.006     -2.53306   -.4528075
#        _cons |   14.07587   .1643173    85.66   0.000     13.74695    14.40479
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       5.78
#                                                   Prob > F        =     0.0195
#                                                   R-squared       =     0.9922
#                                                   Adj R-squared   =     0.9840
#                                                   Within R-sq.    =     0.0906
#                                                   Root MSE        =     0.1913
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1713761     .07131    -2.40   0.019    -.3141186   -.0286335
#        _cons |   3.260518   .0225502   144.59   0.000     3.215379    3.305657
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      39.89
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9774
#                                                   Adj R-squared   =     0.9536
#                                                   Within R-sq.    =     0.4075
#                                                   Root MSE        =     0.6397
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.505757   .2384124    -6.32   0.000    -1.982992   -1.028523
#        _cons |   7.475259   .0753926    99.15   0.000     7.324345    7.626174
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       1.79
#                                                   Prob > F        =     0.1856
#                                                   R-squared       =     0.5625
#                                                   Adj R-squared   =     0.1023
#                                                   Within R-sq.    =     0.0300
#                                                   Root MSE        =     0.2113
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1054903   .0787522     1.34   0.186    -.0521492    .2631299
#        _cons |   4.488265   .0249036   180.23   0.000     4.438415    4.538115
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      16.37
#                                                   Prob > F        =     0.0002
#                                                   R-squared       =     0.9923
#                                                   Adj R-squared   =     0.9843
#                                                   Within R-sq.    =     0.2201
#                                                   Root MSE        =     1.3100
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.975169   .4882044    -4.05   0.000    -2.952416   -.9979217
#        _cons |   14.33499   .1543838    92.85   0.000     14.02596    14.64402
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.48
#                                                   Prob > F        =     0.4894
#                                                   R-squared       =     0.9893
#                                                   Adj R-squared   =     0.9780
#                                                   Within R-sq.    =     0.0083
#                                                   Root MSE        =     1.1198
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2903374   .4173394    -0.70   0.489    -1.125733    .5450581
#        _cons |   11.40037   .1319743    86.38   0.000      11.1362    11.66455
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.97
#                                                   Prob > F        =     0.3279
#                                                   R-squared       =     0.9698
#                                                   Adj R-squared   =     0.9380
#                                                   Within R-sq.    =     0.0165
#                                                   Root MSE        =     1.2240
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.4501351   .4561703    -0.99   0.328    -1.363259    .4629889
#        _cons |   8.987454   .1442537    62.30   0.000     8.698699    9.276209
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      24.80
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9881
#                                                   Adj R-squared   =     0.9755
#                                                   Within R-sq.    =     0.2995
#                                                   Root MSE        =     1.2736
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.363534   .4746518    -4.98   0.000    -3.313652   -1.413415
#        _cons |   12.30108   .1500981    81.95   0.000     12.00063    12.60154
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       1.69
#                                                   Prob > F        =     0.1992
#                                                   R-squared       =     0.9975
#                                                   Adj R-squared   =     0.9949
#                                                   Within R-sq.    =     0.0283
#                                                   Root MSE        =     2.2107
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.070004   .8238765    -1.30   0.199    -2.719172    .5791643
#        _cons |   32.71228   .2605326   125.56   0.000     32.19077     33.2338
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------China---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      15.57
#                                                   Prob > F        =     0.0002
#                                                   R-squared       =     0.8435
#                                                   Adj R-squared   =     0.6789
#                                                   Within R-sq.    =     0.2116
#                                                   Root MSE        =     0.8644
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.271119   .3221504    -3.95   0.000    -1.915973   -.6262648
#        _cons |   5.934843   .1018729    58.26   0.000     5.730922    6.138764
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       8.92
#                                                   Prob > F        =     0.0041
#                                                   R-squared       =     0.9924
#                                                   Adj R-squared   =     0.9845
#                                                   Within R-sq.    =     0.1333
#                                                   Root MSE        =     3.2379
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -3.603998   1.206684    -2.99   0.004    -6.019438   -1.188558
#        _cons |   28.60868   .3815869    74.97   0.000     27.84485    29.37251
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       1.06
#                                                   Prob > F        =     0.3079
#                                                   R-squared       =     0.9448
#                                                   Adj R-squared   =     0.8868
#                                                   Within R-sq.    =     0.0179
#                                                   Root MSE        =     0.7260
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2783137   .2705809    -1.03   0.308    -.8199402    .2633129
#        _cons |   6.482387   .0855652    75.76   0.000      6.31111    6.653664
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      14.70
#                                                   Prob > F        =     0.0003
#                                                   R-squared       =     0.9920
#                                                   Adj R-squared   =     0.9835
#                                                   Within R-sq.    =     0.2022
#                                                   Root MSE        =     2.0830
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.975993   .7763044    -3.83   0.000    -4.529935   -1.422051
#        _cons |   19.70393    .245489    80.26   0.000     19.21253    20.19533
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.01
#                                                   Prob > F        =     0.9204
#                                                   R-squared       =     0.9888
#                                                   Adj R-squared   =     0.9771
#                                                   Within R-sq.    =     0.0002
#                                                   Root MSE        =     1.9048
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0712455   .7098631    -0.10   0.920    -1.492191      1.3497
#        _cons |   15.85812   .2244784    70.64   0.000     15.40878    16.30746
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       2.16
#                                                   Prob > F        =     0.1473
#                                                   R-squared       =     0.9880
#                                                   Adj R-squared   =     0.9753
#                                                   Within R-sq.    =     0.0359
#                                                   Root MSE        =     1.2738
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -.697206   .4747242    -1.47   0.147     -1.64747    .2530577
#        _cons |    11.9719    .150121    79.75   0.000      11.6714     12.2724
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       6.68
#                                                   Prob > F        =     0.0123
#                                                   R-squared       =     0.9853
#                                                   Adj R-squared   =     0.9698
#                                                   Within R-sq.    =     0.1032
#                                                   Root MSE        =     2.8938
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.786671   1.078473    -2.58   0.012     -4.94547   -.6278733
#        _cons |   19.98034   .3410431    58.59   0.000     19.29767    20.66301
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       5.08
#                                                   Prob > F        =     0.0280
#                                                   R-squared       =     0.7324
#                                                   Adj R-squared   =     0.4510
#                                                   Within R-sq.    =     0.0805
#                                                   Root MSE        =     0.4730
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .3972996   .1762875     2.25   0.028     .0444219    .7501773
#        _cons |    4.87773    .055747    87.50   0.000      4.76614     4.98932
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      11.57
#                                                   Prob > F        =     0.0012
#                                                   R-squared       =     0.9927
#                                                   Adj R-squared   =     0.9849
#                                                   Within R-sq.    =     0.1664
#                                                   Root MSE        =     0.2381
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -.301933   .0887504    -3.40   0.001    -.4795862   -.1242799
#        _cons |   2.901391   .0280653   103.38   0.000     2.845212     2.95757
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------France---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       3.56
#                                                   Prob > F        =     0.0643
#                                                   R-squared       =     0.7657
#                                                   Adj R-squared   =     0.5192
#                                                   Within R-sq.    =     0.0578
#                                                   Root MSE        =     0.5083
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |     .35723   .1894393     1.89   0.064    -.0219739     .736434
#        _cons |    4.99276    .059906    83.34   0.000     4.872845    5.112675
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       6.89
#                                                   Prob > F        =     0.0111
#                                                   R-squared       =     0.9964
#                                                   Adj R-squared   =     0.9927
#                                                   Within R-sq.    =     0.1062
#                                                   Root MSE        =     0.1629
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1593423   .0607106     2.62   0.011     .0378168    .2808677
#        _cons |   2.836593   .0191984   147.75   0.000     2.798163    2.875023
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       9.69
#                                                   Prob > F        =     0.0029
#                                                   R-squared       =     0.6152
#                                                   Adj R-squared   =     0.2105
#                                                   Within R-sq.    =     0.1432
#                                                   Root MSE        =     0.3017
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.3501083   .1124447    -3.11   0.003    -.5751908   -.1250258
#        _cons |   4.511713   .0355581   126.88   0.000     4.440535     4.58289
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
# ...
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.58
#                                                   Prob > F        =     0.4502
#                                                   R-squared       =     0.8584
#                                                   Adj R-squared   =     0.7094
#                                                   Within R-sq.    =     0.0099
#                                                   Root MSE        =     0.5509
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1560824   .2053022    -0.76   0.450    -.5670394    .2548745
#        _cons |   3.823371   .0649222    58.89   0.000     3.693415    3.953327
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------Viet_Nam---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       4.09
#                                                   Prob > F        =     0.0477
#                                                   R-squared       =     0.8294
#                                                   Adj R-squared   =     0.6501
#                                                   Within R-sq.    =     0.0659
#                                                   Root MSE        =     0.3893
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2934429   .1450721    -2.02   0.048    -.5838362   -.0030495
#        _cons |   4.160229   .0458758    90.68   0.000     4.068399    4.252059
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      83.04
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9880
#                                                   Adj R-squared   =     0.9753
#                                                   Within R-sq.    =     0.5888
#                                                   Root MSE        =     0.9360
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   3.178842   .3488434     9.11   0.000     2.480556    3.877128
#        _cons |   9.188781    .110314    83.30   0.000     8.967963    9.409598
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.00
#                                                   Prob > F        =     0.9682
#                                                   R-squared       =     0.9994
#                                                   Adj R-squared   =     0.9988
#                                                   Within R-sq.    =     0.0000
#                                                   Root MSE        =     0.0799
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0011916   .0297803    -0.04   0.968    -.0608033    .0584201
#        _cons |   2.479681   .0094174   263.31   0.000      2.46083    2.498532
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      15.17
#                                                   Prob > F        =     0.0003
#                                                   R-squared       =     0.9290
#                                                   Adj R-squared   =     0.8543
#                                                   Within R-sq.    =     0.2073
#                                                   Root MSE        =     0.5317
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .7718085   .1981598     3.89   0.000     .3751486    1.168468
#        _cons |   3.270193   .0626636    52.19   0.000     3.144759    3.395628
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      53.73
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9890
#                                                   Adj R-squared   =     0.9775
#                                                   Within R-sq.    =     0.4809
#                                                   Root MSE        =     0.2665
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .7280486    .099322     7.33   0.000      .529234    .9268633
#        _cons |   2.858887   .0314084    91.02   0.000     2.796016    2.921758
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      39.20
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9958
#                                                   Adj R-squared   =     0.9913
#                                                   Within R-sq.    =     0.4033
#                                                   Root MSE        =     0.1749
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .4081366     .06519     6.26   0.000     .2776447    .5386285
#        _cons |   2.812108   .0206149   136.41   0.000     2.770842    2.853373
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      27.04
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.8312
#                                                   Adj R-squared   =     0.6537
#                                                   Within R-sq.    =     0.3180
#                                                   Root MSE        =     0.4805
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .9311823   .1790726     5.20   0.000     .5727296    1.289635
#        _cons |   3.841717   .0566277    67.84   0.000     3.728364     3.95507
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.27
#                                                   Prob > F        =     0.6027
#                                                   R-squared       =     0.9995
#                                                   Adj R-squared   =     0.9989
#                                                   Within R-sq.    =     0.0047
#                                                   Root MSE        =     0.0784
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0152871   .0292055     0.52   0.603     -.043174    .0737481
#        _cons |   2.460855   .0092356   266.45   0.000     2.442368    2.479342
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      10.31
#                                                   Prob > F        =     0.0022
#                                                   R-squared       =     0.9991
#                                                   Adj R-squared   =     0.9981
#                                                   Within R-sq.    =     0.1510
#                                                   Root MSE        =     0.1028
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -.122984   .0382955    -3.21   0.002    -.1996408   -.0463272
#        _cons |   2.472906   .0121101   204.20   0.000     2.448665    2.497147
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout

# %%
def get_result(result_fp):
    with open(result_fp, 'r') as fp:
        result_str = fp.read()
        match_str = re.findall(r'did\t(.*?)\n', result_str)[0]
        star_count = match_str.count('*')
        match_str = match_str.replace(',', '')
        if match_str == '-':# 若匹配到空，判定不显著
            significant = -1
            coff = -999
        else:
            if star_count == 0:
                significant = -1
                coff = float(match_str)
            else:
                coff = float(match_str.split('*')[0])
                if star_count == 1:
                    significant = 0.1
                elif star_count == 2:
                    significant = 0.05
                else:
                    significant = 0.01
    return coff, significant

result_list = []
for region in region_list:
    for sector in sector_list:
        result_fp = project_dir / 'temp' / f'tradewar-{region}-{sector}.txt'
        coff, significant = get_result(result_fp)
        result_list.append((region, sector, coff, significant))
result_df = pd.DataFrame(result_list, columns=['region', 'sector', 'coff', 'significance'])



# # 将coff的值区间缩放至 -1,1
# data = result_df['coff']
# data_t = (data-data.mean())/(data.max()-data.min())
# result_df['coff'] = data_t
result_df.to_csv('C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-trade-war-meso.csv', header=True, index=False)

# %% [markdown]
# # get panel data - pandemic

# %%
country2region_dict = {}
for rg, ct_list in region2countries_dict.items():
    for ct in ct_list:
        country2region_dict[ct] = rg



volume_sum_df = volume_df.groupby(by=['source', 'year', 'month']).sum()
volume_sum_df['region'], volume_sum_df['year'], volume_sum_df['month'] = zip(*volume_sum_df.index)
volume_sum_df.reset_index(drop=True, inplace=True)

# volume_mean_df = volume_sum_df.groupby(by=['year', 'month']).mean()
# volume_mean_df['year'], volume_mean_df['month'] = zip(*volume_mean_df.index)
# volume_mean_df.reset_index(drop=True, inplace=True)



# volume => percentage 转化为占比
years = volume_sum_df['year'].unique()
months = volume_sum_df['month'].unique()
for y in years:
    for m in months:
        query_df = volume_sum_df.query('year == @y and month == @m')[sectors]
        _sum = query_df.sum()
        secter2sum_dict = {s:v for s, v in zip(_sum.index, _sum.tolist())}
        for idx in query_df.index:
            for s, v in secter2sum_dict.items():
                _v = volume_sum_df.loc[idx, s]
                p = _v / v * 100
                volume_sum_df.loc[idx, s] = p

# %%
# empty dir
panel_dir = project_dir / 'panels-pandemic'
for fp in panel_dir.rglob('*.csv'):
    os.remove(fp)

# %%
exp_years = [2020,2021]
com_years = [2018,2019]


def get_did_panel(volume_sum_df, exp_years, com_years, sector, region):
    
    volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
    volume_mean_df['year'], volume_mean_df['month'] = zip(*volume_mean_df.index)
    volume_mean_df.reset_index(drop=True, inplace=True)
    
    com_df = volume_mean_df[['year', 'month', sector]]
    com_df['name'] = 'mean'
    com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
    com_df.loc[com_df.query('year in @exp_years').index, 'time'] = 1
    com_df = com_df.dropna()
    com_df['time'] = com_df['time'].astype('int')
    com_df.loc[:, 'group'] = 0


    exp_df = volume_sum_df.query('region == @region')[['region', 'year', 'month', sector]]
    exp_df = exp_df.rename(columns={'region': 'name'})
    exp_df.loc[exp_df.query('year in @com_years').index, 'time'] = 0
    exp_df.loc[exp_df.query('year in @exp_years').index, 'time'] = 1
    exp_df = exp_df.dropna()
    exp_df['time'] = exp_df['time'].astype('int')
    exp_df.loc[:, 'group'] = 1


    concat_df = pd.concat([exp_df, com_df])
    concat_df['did'] = concat_df.apply(lambda x: x['time'] * x['group'], axis=1)
    concat_df['date'] = concat_df.apply(lambda x: '{}-{}'.format(x['year'], x['month']), axis=1)
    del concat_df['year'], concat_df['month']
    concat_df = concat_df.rename(columns={sector: 'value'})
    # concat_df['value'] = np.log(concat_df['value'] + 1)
    return concat_df

for region in top_countries:
    for sector in sectors:
        panel_df = get_did_panel(volume_sum_df, exp_years, com_years, sector, region)
        panel_df.to_csv(panel_dir / f'{region}-{sector}.csv', header=True, index=False)
# Out:
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\3514503499.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1

# %% [markdown]
# # did-pandemic

# %%
import re
import ipystata

region_list = list(top_countries)
sector_list = sectors


# empty dir
panel_dir = project_dir / 'temp-1'
for fp in panel_dir.rglob('*.txt'):
    os.remove(fp)

# %%
# %%stata -i sector_list -i region_list
# foreach region in `region_list' {
#     display "------------------------`region'---------------------------------"
#     clear
#     cd "C:\shares_TARIFF_project\comtrade_new\DID_country"
#     foreach sector in `sector_list' {
#         import delimited "./panels-pandemic/`region'-`sector'.csv"
#         egen time1 = group(date)
#         xtset time1 group
#         reghdfe value did, absorb(time1 group)
#         outreg2 using "./temp-1/pandemic-`region'-`sector'.txt"
#         clear
#     }
# }
# Out:
# ------------------------Brazil---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.30
#                                                   Prob > F        =     0.5871
#                                                   R-squared       =     0.7722
#                                                   Adj R-squared   =     0.5296
#                                                   Within R-sq.    =     0.0065
#                                                   Root MSE        =     0.4831
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1078796   .1972403    -0.55   0.587    -.5049039    .2891446
#        _cons |   4.116329    .069735    59.03   0.000      3.97596    4.256698
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.15
#                                                   Prob > F        =     0.6997
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9985
#                                                   Within R-sq.    =     0.0033
#                                                   Root MSE        =     0.0853
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0135151   .0348169     0.39   0.700    -.0565677    .0835979
#        _cons |   2.567904   .0123096   208.61   0.000     2.543126    2.592682
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      15.84
#                                                   Prob > F        =     0.0002
#                                                   R-squared       =     0.9981
#                                                   Adj R-squared   =     0.9960
#                                                   Within R-sq.    =     0.2561
#                                                   Root MSE        =     0.1245
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2023592   .0508471    -3.98   0.000    -.3047092   -.1000093
#        _cons |   2.854975   .0179772   158.81   0.000     2.818789    2.891162
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.80
#                                                   Prob > F        =     0.3769
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9985
#                                                   Within R-sq.    =     0.0170
#                                                   Root MSE        =     0.0851
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0309815   .0347257     0.89   0.377    -.0389178    .1008808
#        _cons |   2.585074   .0122774   210.56   0.000     2.560361    2.609787
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       2.01
#                                                   Prob > F        =     0.1630
#                                                   R-squared       =     0.9266
#                                                   Adj R-squared   =     0.8484
#                                                   Within R-sq.    =     0.0419
#                                                   Root MSE        =     0.3124
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1808094   .1275288    -1.42   0.163    -.4375115    .0758927
#        _cons |   3.958342   .0450882    87.79   0.000     3.867584      4.0491
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       8.75
#                                                   Prob > F        =     0.0049
#                                                   R-squared       =     0.8885
#                                                   Adj R-squared   =     0.7697
#                                                   Within R-sq.    =     0.1598
#                                                   Root MSE        =     0.5831
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.7040008   .2380411    -2.96   0.005    -1.183153   -.2248489
#        _cons |   3.809384   .0841602    45.26   0.000     3.639979     3.97879
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      48.20
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9913
#                                                   Adj R-squared   =     0.9821
#                                                   Within R-sq.    =     0.5117
#                                                   Root MSE        =     0.2247
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.6369355   .0917396    -6.94   0.000    -.8215978   -.4522733
#        _cons |   3.255978   .0324348   100.39   0.000      3.19069    3.321266
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       2.30
#                                                   Prob > F        =     0.1364
#                                                   R-squared       =     0.9919
#                                                   Adj R-squared   =     0.9832
#                                                   Within R-sq.    =     0.0476
#                                                   Root MSE        =     0.2491
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1541461   .1016825    -1.52   0.136    -.3588223    .0505302
#        _cons |   2.899489   .0359502    80.65   0.000     2.827125    2.971853
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       7.99
#                                                   Prob > F        =     0.0069
#                                                   R-squared       =     0.6832
#                                                   Adj R-squared   =     0.3457
#                                                   Within R-sq.    =     0.1480
#                                                   Root MSE        =     0.8047
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.9286404   .3285187    -2.83   0.007    -1.589914   -.2673666
#        _cons |   4.300985   .1161489    37.03   0.000      4.06719    4.534781
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------Canada---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.52
#                                                   Prob > F        =     0.4739
#                                                   R-squared       =     0.9899
#                                                   Adj R-squared   =     0.9792
#                                                   Within R-sq.    =     0.0112
#                                                   Root MSE        =     1.4322
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .4221904   .5846928     0.72   0.474    -.7547352    1.599116
#        _cons |   13.36385   .2067201    64.65   0.000     12.94775    13.77996
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       7.95
#                                                   Prob > F        =     0.0071
#                                                   R-squared       =     0.9937
#                                                   Adj R-squared   =     0.9870
#                                                   Within R-sq.    =     0.1474
#                                                   Root MSE        =     0.1841
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2119418   .0751588    -2.82   0.007    -.3632285    -.060655
#        _cons |   3.188666   .0265726   120.00   0.000     3.135178    3.242154
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      20.05
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9865
#                                                   Adj R-squared   =     0.9720
#                                                   Within R-sq.    =     0.3036
#                                                   Root MSE        =     0.3819
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.6982505   .1559249    -4.48   0.000    -1.012111   -.3843899
#        _cons |   6.783473   .0551278   123.05   0.000     6.672507     6.89444
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      24.21
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.7383
#                                                   Adj R-squared   =     0.4595
#                                                   Within R-sq.    =     0.3449
#                                                   Root MSE        =     0.2765
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.5554329   .1128751    -4.92   0.000    -.7826387   -.3282271
#        _cons |   4.554979   .0399074   114.14   0.000      4.47465    4.635308
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      15.96
#                                                   Prob > F        =     0.0002
#                                                   R-squared       =     0.9927
#                                                   Adj R-squared   =     0.9849
#                                                   Within R-sq.    =     0.2576
#                                                   Root MSE        =     1.2771
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   2.082813   .5213806     3.99   0.000     1.033329    3.132298
#        _cons |   13.35731   .1843359    72.46   0.000     12.98626    13.72836
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.80
#                                                   Prob > F        =     0.3772
#                                                   R-squared       =     0.9749
#                                                   Adj R-squared   =     0.9481
#                                                   Within R-sq.    =     0.0170
#                                                   Root MSE        =     1.6889
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.6148423   .6894761    -0.89   0.377    -2.002686     .773001
#        _cons |   11.28069   .2437666    46.28   0.000     10.79001    11.77136
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      15.60
#                                                   Prob > F        =     0.0003
#                                                   R-squared       =     0.9569
#                                                   Adj R-squared   =     0.9109
#                                                   Within R-sq.    =     0.2532
#                                                   Root MSE        =     1.3006
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.096912    .530982    -3.95   0.000    -3.165723     -1.0281
#        _cons |    8.82606   .1877305    47.01   0.000     8.448178    9.203942
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       8.58
#                                                   Prob > F        =     0.0053
#                                                   R-squared       =     0.9605
#                                                   Adj R-squared   =     0.9183
#                                                   Within R-sq.    =     0.1572
#                                                   Root MSE        =     2.0033
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.395835   .8178355    -2.93   0.005    -4.042052   -.7496175
#        _cons |   11.24278   .2891485    38.88   0.000     10.66076    11.82481
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       1.94
#                                                   Prob > F        =     0.1702
#                                                   R-squared       =     0.9968
#                                                   Adj R-squared   =     0.9933
#                                                   Within R-sq.    =     0.0405
#                                                   Root MSE        =     2.5394
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   1.444524   1.036691     1.39   0.170    -.6422269    3.531275
#        _cons |    32.1754   .3665257    87.78   0.000     31.43762    32.91318
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------China---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      21.71
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.6909
#                                                   Adj R-squared   =     0.3616
#                                                   Within R-sq.    =     0.3207
#                                                   Root MSE        =     0.8786
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.671463   .3586983    -4.66   0.000    -2.393485   -.9494407
#        _cons |   5.376329    .126819    42.39   0.000     5.121056    5.631602
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       3.70
#                                                   Prob > F        =     0.0607
#                                                   R-squared       =     0.9790
#                                                   Adj R-squared   =     0.9566
#                                                   Within R-sq.    =     0.0744
#                                                   Root MSE        =     5.0466
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -3.96241   2.060262    -1.92   0.061    -8.109501    .1846822
#        _cons |    26.9983   .7284125    37.06   0.000     25.53208    28.46451
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.01
#                                                   Prob > F        =     0.9271
#                                                   R-squared       =     0.8893
#                                                   Adj R-squared   =     0.7714
#                                                   Within R-sq.    =     0.0002
#                                                   Root MSE        =     1.0474
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0393236   .4276025    -0.09   0.927    -.9000429    .8213957
#        _cons |   6.355575   .1511803    42.04   0.000     6.051265    6.659885
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       9.61
#                                                   Prob > F        =     0.0033
#                                                   R-squared       =     0.9830
#                                                   Adj R-squared   =     0.9650
#                                                   Within R-sq.    =     0.1729
#                                                   Root MSE        =     2.7300
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -3.455559   1.114501    -3.10   0.003    -5.698934   -1.212184
#        _cons |   18.37929   .3940358    46.64   0.000     17.58614    19.17244
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       8.12
#                                                   Prob > F        =     0.0065
#                                                   R-squared       =     0.9806
#                                                   Adj R-squared   =     0.9598
#                                                   Within R-sq.    =     0.1500
#                                                   Root MSE        =     2.4040
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.796234   .9814346    -2.85   0.007     -4.77176    -.820709
#        _cons |   15.89108   .3469895    45.80   0.000     15.19263    16.58953
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      28.40
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9712
#                                                   Adj R-squared   =     0.9406
#                                                   Within R-sq.    =     0.3817
#                                                   Root MSE        =     1.7485
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -3.803827    .713838    -5.33   0.000    -5.240708   -2.366945
#        _cons |    11.7331   .2523798    46.49   0.000     11.22509    12.24112
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       0.11
#                                                   Prob > F        =     0.7427
#                                                   R-squared       =     0.9755
#                                                   Adj R-squared   =     0.9495
#                                                   Within R-sq.    =     0.0024
#                                                   Root MSE        =     3.5563
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.4794871   1.451866    -0.33   0.743    -3.401942    2.442968
#        _cons |   18.67724   .5133123    36.39   0.000     17.64399    19.71048
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       2.26
#                                                   Prob > F        =     0.1396
#                                                   R-squared       =     0.6620
#                                                   Adj R-squared   =     0.3019
#                                                   Within R-sq.    =     0.0468
#                                                   Root MSE        =     0.9772
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |    .599758   .3989207     1.50   0.140    -.2032276    1.402744
#        _cons |   5.055878   .1410398    35.85   0.000     4.771979    5.339776
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      33.84
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9967
#                                                   Adj R-squared   =     0.9933
#                                                   Within R-sq.    =     0.4238
#                                                   Root MSE        =     0.1752
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.4160151   .0715154    -5.82   0.000    -.5599681    -.272062
#        _cons |   2.772476   .0252845   109.65   0.000     2.721581    2.823371
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------France---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       3.57
#                                                   Prob > F        =     0.0651
#                                                   R-squared       =     0.7172
#                                                   Adj R-squared   =     0.4159
#                                                   Within R-sq.    =     0.0720
#                                                   Root MSE        =     0.6116
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.4718554    .249696    -1.89   0.065    -.9744674    .0307567
#        _cons |   5.176439   .0882809    58.64   0.000     4.998739     5.35414
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       5.50
#                                                   Prob > F        =     0.0233
#                                                   R-squared       =     0.9918
#                                                   Adj R-squared   =     0.9831
#                                                   Within R-sq.    =     0.1069
#                                                   Root MSE        =     0.2346
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |    .224696   .0957782     2.35   0.023     .0319044    .4174876
#        _cons |   2.911033   .0338627    85.97   0.000     2.842871    2.979195
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      15.48
#                                                   Prob > F        =     0.0003
#                                                   R-squared       =     0.8151
#                                                   Adj R-squared   =     0.6182
#                                                   Within R-sq.    =     0.2518
#                                                   Root MSE        =     0.3328
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.5344745   .1358482    -3.93   0.000    -.8079227   -.2610262
#        _cons |   4.362627   .0480296    90.83   0.000     4.265949    4.459306
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
# ...
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      26.58
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9273
#                                                   Adj R-squared   =     0.8499
#                                                   Within R-sq.    =     0.3662
#                                                   Root MSE        =     0.5232
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.101208   .2136022    -5.16   0.000    -1.531167   -.6712489
#        _cons |   3.779108   .0755198    50.04   0.000     3.627094    3.931121
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------Viet_Nam---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       1.11
#                                                   Prob > F        =     0.2982
#                                                   R-squared       =     0.8733
#                                                   Adj R-squared   =     0.7383
#                                                   Within R-sq.    =     0.0235
#                                                   Root MSE        =     0.3907
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1678301   .1594997    -1.05   0.298    -.4888862    .1532261
#        _cons |   4.029612   .0563916    71.46   0.000     3.916101    4.143122
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      13.97
#                                                   Prob > F        =     0.0005
#                                                   R-squared       =     0.9762
#                                                   Adj R-squared   =     0.9509
#                                                   Within R-sq.    =     0.2330
#                                                   Root MSE        =     1.6903
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   2.579429   .6900538     3.74   0.001     1.190423    3.968435
#        _cons |   10.63532   .2439709    43.59   0.000     10.14423    11.12641
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      16.55
#                                                   Prob > F        =     0.0002
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9986
#                                                   Within R-sq.    =     0.2645
#                                                   Root MSE        =     0.0867
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1439385   .0353851     4.07   0.000     .0727119     .215165
#        _cons |   2.480154   .0125105   198.25   0.000     2.454972    2.505337
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      77.14
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.8135
#                                                   Adj R-squared   =     0.6148
#                                                   Within R-sq.    =     0.6264
#                                                   Root MSE        =     0.7249
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   2.599131   .2959312     8.78   0.000     2.003452     3.19481
#        _cons |    3.57972   .1046275    34.21   0.000     3.369116    3.790324
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =     126.39
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9737
#                                                   Adj R-squared   =     0.9456
#                                                   Within R-sq.    =     0.7332
#                                                   Root MSE        =     0.3014
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   1.383226   .1230388    11.24   0.000     1.135562     1.63089
#        _cons |   3.175582   .0435008    73.00   0.000     3.088019    3.263145
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       2.29
#                                                   Prob > F        =     0.1373
#                                                   R-squared       =     0.9902
#                                                   Adj R-squared   =     0.9797
#                                                   Within R-sq.    =     0.0474
#                                                   Root MSE        =     0.2455
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1515439   .1002121     1.51   0.137    -.0501726    .3532605
#        _cons |   3.005809   .0354303    84.84   0.000     2.934492    3.077127
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      75.23
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.8122
#                                                   Adj R-squared   =     0.6122
#                                                   Within R-sq.    =     0.6206
#                                                   Root MSE        =     0.9181
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   3.250889   .3748063     8.67   0.000     2.496443    4.005335
#        _cons |   4.211475    .132514    31.78   0.000     3.944738    4.478212
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =      22.94
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9986
#                                                   Within R-sq.    =     0.3328
#                                                   Root MSE        =     0.0847
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1656586   .0345861     4.79   0.000     .0960403    .2352769
#        _cons |   2.468622    .012228   201.88   0.000     2.444008    2.493236
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 96 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =         96
# Absorbing 2 HDFE groups                           F(   1,     46) =       8.80
#                                                   Prob > F        =     0.0048
#                                                   R-squared       =     0.9994
#                                                   Adj R-squared   =     0.9987
#                                                   Within R-sq.    =     0.1606
#                                                   Root MSE        =     0.0840
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1016943    .034277     2.97   0.005     .0326983    .1706903
#        _cons |   2.416795   .0121187   199.43   0.000     2.392401    2.441188
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        48           0          48     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout

# %%
def get_result(result_fp):
    with open(result_fp, 'r') as fp:
        result_str = fp.read()
        match_str = re.findall(r'did\t(.*?)\n', result_str)[0]
        star_count = match_str.count('*')
        match_str = match_str.replace(',', '')
        if match_str == '-':# 若匹配到空，判定不显著
            significant = -1
            coff = -999
        else:
            if star_count == 0:
                significant = -1
                coff = float(match_str)
            else:
                coff = float(match_str.split('*')[0])
                if star_count == 1:
                    significant = 0.1
                elif star_count == 2:
                    significant = 0.05
                else:
                    significant = 0.01
    return coff, significant

result_list = []
for region in region_list:
    for sector in sector_list:
        result_fp = project_dir / 'temp-1' / f'pandemic-{region}-{sector}.txt'
        coff, significant = get_result(result_fp)
        result_list.append((region, sector, coff, significant))
result_df = pd.DataFrame(result_list, columns=['region', 'sector', 'coff', 'significance'])


# # 将coff的值区间缩放至 -1,1
# data = result_df['coff']
# data_t = (data-data.mean())/(data.max()-data.min())
# result_df['coff'] = data_t
result_df.to_csv('C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-pandemic-meso-true.csv', header=True, index=False)
#result_df.to_csv('C:\\shares_TARIFF_project\\comtrade_new\\DID_country_cancel2018\\did-summary\\did-result-pandemic-meso-true.csv', header=True, index=False)
# result_df

# %% [markdown]
# # get panel data -two events

# %%
country2region_dict = {}
for rg, ct_list in region2countries_dict.items():
    for ct in ct_list:
        country2region_dict[ct] = rg



volume_sum_df = volume_df.groupby(by=['source', 'year', 'month']).sum()
volume_sum_df['region'], volume_sum_df['year'], volume_sum_df['month'] = zip(*volume_sum_df.index)
volume_sum_df.reset_index(drop=True, inplace=True)

# volume_mean_df = volume_sum_df.groupby(by=['year', 'month']).mean()
# volume_mean_df['year'], volume_mean_df['month'] = zip(*volume_mean_df.index)
# volume_mean_df.reset_index(drop=True, inplace=True)



# volume => percentage 转化为占比
years = volume_sum_df['year'].unique()
months = volume_sum_df['month'].unique()
for y in years:
    for m in months:
        query_df = volume_sum_df.query('year == @y and month == @m')[sectors]
        _sum = query_df.sum()
        secter2sum_dict = {s:v for s, v in zip(_sum.index, _sum.tolist())}
        for idx in query_df.index:
            for s, v in secter2sum_dict.items():
                _v = volume_sum_df.loc[idx, s]
                p = _v / v * 100
                volume_sum_df.loc[idx, s] = p
# Out:
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\265871262.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_sum_df = volume_df.groupby(by=['source', 'year', 'month']).sum()

# %%
# empty dir
panel_dir = project_dir / 'panels-two-events'
for fp in panel_dir.rglob('*.csv'):
    os.remove(fp)

# %%
exp_years = [2020,2021]
com_years = [2015,2016,2017]


def get_did_panel(volume_sum_df, exp_years, com_years, sector, region):
    
    volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
    volume_mean_df['year'], volume_mean_df['month'] = zip(*volume_mean_df.index)
    volume_mean_df.reset_index(drop=True, inplace=True)
    
    com_df = volume_mean_df[['year', 'month', sector]]
    com_df['name'] = 'mean'
    com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
    com_df.loc[com_df.query('year in @exp_years').index, 'time'] = 1
    com_df = com_df.dropna()
    com_df['time'] = com_df['time'].astype('int')
    com_df.loc[:, 'group'] = 0


    exp_df = volume_sum_df.query('region == @region')[['region', 'year', 'month', sector]]
    exp_df = exp_df.rename(columns={'region': 'name'})
    exp_df.loc[exp_df.query('year in @com_years').index, 'time'] = 0
    exp_df.loc[exp_df.query('year in @exp_years').index, 'time'] = 1
    exp_df = exp_df.dropna()
    exp_df['time'] = exp_df['time'].astype('int')
    exp_df.loc[:, 'group'] = 1


    concat_df = pd.concat([exp_df, com_df])
    concat_df['did'] = concat_df.apply(lambda x: x['time'] * x['group'], axis=1)
    concat_df['date'] = concat_df.apply(lambda x: '{}-{}'.format(x['year'], x['month']), axis=1)
    del concat_df['year'], concat_df['month']
    concat_df = concat_df.rename(columns={sector: 'value'})
    # concat_df['value'] = np.log(concat_df['value'] + 1)
    return concat_df

for region in top_countries:
    for sector in sectors:
        panel_df = get_did_panel(volume_sum_df, exp_years, com_years, sector, region)
        panel_df.to_csv(panel_dir / f'{region}-{sector}.csv', header=True, index=False)
# Out:
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   volume_mean_df = volume_sum_df.query('region != @region').groupby(by=['year', 'month']).mean()
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['name'] = 'mean'
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[com_df.query('year in @com_years').index, 'time'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time'] = com_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df.loc[:, 'group'] = 0
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df['time'] = exp_df['time'].astype('int')
# C:\Users\Ki Siyuan\AppData\Local\Temp\ipykernel_3336\2979130469.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exp_df.loc[:, 'group'] = 1

# %% [markdown]
# # DID-two-events

# %%
import re
import ipystata

region_list = list(top_countries)
sector_list = sectors


# empty dir
panel_dir = project_dir / 'temp-2'
for fp in panel_dir.rglob('*.txt'):
    os.remove(fp)

# %%
# %%stata -i sector_list -i region_list
# foreach region in `region_list' {
#     display "------------------------`region'---------------------------------"
#     clear
#     cd "C:\shares_TARIFF_project\comtrade_new\DID_country"
#     foreach sector in `sector_list' {
#         import delimited "./panels-two-events/`region'-`sector'.csv"
#         egen time1 = group(date)
#         xtset time1 group
#         reghdfe value did, absorb(time1 group)
#         outreg2 using "./temp-2/two-events-`region'-`sector'.txt"
#         clear
#     }
# }
# Out:
# ------------------------Brazil---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       8.17
#                                                   Prob > F        =     0.0059
#                                                   R-squared       =     0.7378
#                                                   Adj R-squared   =     0.4621
#                                                   Within R-sq.    =     0.1235
#                                                   Root MSE        =     0.4633
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.4936078   .1726637    -2.86   0.006    -.8392318   -.1479839
#        _cons |   4.282851   .0546011    78.44   0.000     4.173555    4.392147
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       3.02
#                                                   Prob > F        =     0.0874
#                                                   R-squared       =     0.9993
#                                                   Adj R-squared   =     0.9986
#                                                   Within R-sq.    =     0.0495
#                                                   Root MSE        =     0.0816
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0528968   .0304214    -1.74   0.087    -.1137918    .0079981
#        _cons |   2.583707   .0096201   268.57   0.000      2.56445    2.602964
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      20.26
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9979
#                                                   Adj R-squared   =     0.9957
#                                                   Within R-sq.    =     0.2589
#                                                   Root MSE        =     0.1290
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.2164239   .0480801    -4.50   0.000    -.3126667    -.120181
#        _cons |   2.845175   .0152043   187.13   0.000     2.814741     2.87561
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       6.29
#                                                   Prob > F        =     0.0150
#                                                   R-squared       =     0.9996
#                                                   Adj R-squared   =     0.9991
#                                                   Within R-sq.    =     0.0978
#                                                   Root MSE        =     0.0664
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .0620282   .0247336     2.51   0.015     .0125184    .1115379
#        _cons |   2.554892   .0078215   326.65   0.000     2.539236    2.570548
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       1.18
#                                                   Prob > F        =     0.2812
#                                                   R-squared       =     0.9493
#                                                   Adj R-squared   =     0.8960
#                                                   Within R-sq.    =     0.0200
#                                                   Root MSE        =     0.2564
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -.103947   .0955576    -1.09   0.281    -.2952263    .0873323
#        _cons |   3.906008    .030218   129.26   0.000      3.84552    3.966495
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      12.08
#                                                   Prob > F        =     0.0010
#                                                   R-squared       =     0.9204
#                                                   Adj R-squared   =     0.8366
#                                                   Within R-sq.    =     0.1724
#                                                   Root MSE        =     0.4678
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.6060802   .1743499    -3.48   0.001    -.9550794    -.257081
#        _cons |   3.744597   .0551343    67.92   0.000     3.634234    3.854961
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      81.65
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9852
#                                                   Adj R-squared   =     0.9697
#                                                   Within R-sq.    =     0.5847
#                                                   Root MSE        =     0.2750
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.9260823   .1024902    -9.04   0.000    -1.131239   -.7209258
#        _cons |   3.374386   .0324103   104.11   0.000     3.309509    3.439262
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      11.97
#                                                   Prob > F        =     0.0010
#                                                   R-squared       =     0.9904
#                                                   Adj R-squared   =     0.9803
#                                                   Within R-sq.    =     0.1711
#                                                   Root MSE        =     0.2618
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.3375233   .0975491    -3.46   0.001     -.532789   -.1422575
#        _cons |   2.969893   .0308477    96.28   0.000     2.908144    3.031641
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      13.08
#                                                   Prob > F        =     0.0006
#                                                   R-squared       =     0.6807
#                                                   Adj R-squared   =     0.3448
#                                                   Within R-sq.    =     0.1840
#                                                   Root MSE        =     0.7646
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.030573   .2849524    -3.62   0.001    -1.600968   -.4601792
#        _cons |   4.329545   .0901099    48.05   0.000     4.149171     4.50992
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------Canada---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       3.75
#                                                   Prob > F        =     0.0576
#                                                   R-squared       =     0.9900
#                                                   Adj R-squared   =     0.9795
#                                                   Within R-sq.    =     0.0608
#                                                   Root MSE        =     1.4829
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -1.070743   .5526486    -1.94   0.058     -2.17699    .0355032
#        _cons |   14.05944   .1747628    80.45   0.000     13.70961    14.40926
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      25.89
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9918
#                                                   Adj R-squared   =     0.9832
#                                                   Within R-sq.    =     0.3087
#                                                   Root MSE        =     0.2021
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.3833179   .0753283    -5.09   0.000    -.5341039   -.2325318
#        _cons |   3.253258   .0238209   136.57   0.000     3.205575    3.300941
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      84.15
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9757
#                                                   Adj R-squared   =     0.9501
#                                                   Within R-sq.    =     0.5920
#                                                   Root MSE        =     0.6447
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.204008   .2402593    -9.17   0.000    -2.684939   -1.723077
#        _cons |   7.477704   .0759767    98.42   0.000      7.32562    7.629788
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      22.20
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.7282
#                                                   Adj R-squared   =     0.4424
#                                                   Within R-sq.    =     0.2768
#                                                   Root MSE        =     0.2562
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.4499425   .0954933    -4.71   0.000    -.6410932   -.2587918
#        _cons |   4.487586   .0301976   148.61   0.000     4.427139    4.548033
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.04
#                                                   Prob > F        =     0.8501
#                                                   R-squared       =     0.9904
#                                                   Adj R-squared   =     0.9804
#                                                   Within R-sq.    =     0.0006
#                                                   Root MSE        =     1.5217
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1076445   .5671101     0.19   0.850     -1.02755    1.242839
#        _cons |   14.28785    .179336    79.67   0.000     13.92887    14.64683
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       2.73
#                                                   Prob > F        =     0.1037
#                                                   R-squared       =     0.9812
#                                                   Adj R-squared   =     0.9615
#                                                   Within R-sq.    =     0.0450
#                                                   Root MSE        =     1.4693
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.9051798   .5475902    -1.65   0.104    -2.001301    .1909412
#        _cons |   11.40251   .1731632    65.85   0.000     11.05589    11.74913
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      29.95
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9639
#                                                   Adj R-squared   =     0.9258
#                                                   Within R-sq.    =     0.3406
#                                                   Root MSE        =     1.2487
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.547047   .4653774    -5.47   0.000    -3.478601   -1.615493
#        _cons |    9.01633   .1471652    61.27   0.000     8.721747    9.310913
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      42.38
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9700
#                                                   Adj R-squared   =     0.9385
#                                                   Within R-sq.    =     0.4222
#                                                   Root MSE        =     1.9618
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -4.759369   .7311164    -6.51   0.000    -6.222857    -3.29588
#        _cons |   12.33595   .2311993    53.36   0.000     11.87315    12.79874
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.15
#                                                   Prob > F        =     0.7009
#                                                   R-squared       =     0.9966
#                                                   Adj R-squared   =     0.9931
#                                                   Within R-sq.    =     0.0026
#                                                   Root MSE        =     2.6034
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .3745205   .9702196     0.39   0.701    -1.567585    2.316626
#        _cons |    32.6819   .3068104   106.52   0.000     32.06775    33.29605
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------China---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =     172.36
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9137
#                                                   Adj R-squared   =     0.8229
#                                                   Within R-sq.    =     0.7482
#                                                   Root MSE        =     0.6014
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -2.942582   .2241338   -13.13   0.000    -3.391234   -2.493929
#        _cons |   5.955018   .0708773    84.02   0.000     5.813142    6.096894
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      20.94
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9852
#                                                   Adj R-squared   =     0.9696
#                                                   Within R-sq.    =     0.2653
#                                                   Root MSE        =     4.4368
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -7.566407   1.653495    -4.58   0.000    -10.87624   -4.256578
#        _cons |   28.67665    .522881    54.84   0.000     27.62999    29.72331
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.93
#                                                   Prob > F        =     0.3396
#                                                   R-squared       =     0.9212
#                                                   Adj R-squared   =     0.8382
#                                                   Within R-sq.    =     0.0157
#                                                   Root MSE        =     0.8851
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.3176372    .329855    -0.96   0.340    -.9779138    .3426394
#        _cons |   6.472841   .1043093    62.05   0.000     6.264043    6.681639
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      60.62
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9902
#                                                   Adj R-squared   =     0.9799
#                                                   Within R-sq.    =     0.5110
#                                                   Root MSE        =     2.2165
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -6.431552   .8260576    -7.79   0.000    -8.085086   -4.778018
#        _cons |   19.76024   .2612223    75.65   0.000     19.23734    20.28313
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      16.25
#                                                   Prob > F        =     0.0002
#                                                   R-squared       =     0.9878
#                                                   Adj R-squared   =     0.9750
#                                                   Within R-sq.    =     0.2188
#                                                   Root MSE        =     1.9088
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -2.86748    .711383    -4.03   0.000    -4.291468   -1.443492
#        _cons |   15.90163   .2249591    70.69   0.000     15.45133    16.35194
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      68.00
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9816
#                                                   Adj R-squared   =     0.9622
#                                                   Within R-sq.    =     0.5397
#                                                   Root MSE        =     1.4646
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -4.501033    .545832    -8.25   0.000    -5.593634   -3.408431
#        _cons |   12.03247   .1726072    69.71   0.000     11.68696    12.37798
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       7.17
#                                                   Prob > F        =     0.0096
#                                                   R-squared       =     0.9811
#                                                   Adj R-squared   =     0.9613
#                                                   Within R-sq.    =     0.1100
#                                                   Root MSE        =     3.2735
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -3.266159   1.219975    -2.68   0.010    -5.708204   -.8241136
#        _cons |   19.98215   .3857899    51.80   0.000     19.20991    20.75439
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      10.37
#                                                   Prob > F        =     0.0021
#                                                   R-squared       =     0.6660
#                                                   Adj R-squared   =     0.3147
#                                                   Within R-sq.    =     0.1517
#                                                   Root MSE        =     0.8308
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .9970576   .3096154     3.22   0.002     .3772951     1.61682
#        _cons |   4.856264    .097909    49.60   0.000     4.660278    5.052251
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      88.29
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9950
#                                                   Adj R-squared   =     0.9898
#                                                   Within R-sq.    =     0.6035
#                                                   Root MSE        =     0.2050
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.7179481   .0764083    -9.40   0.000    -.8708959   -.5650003
#        _cons |   2.897805   .0241624   119.93   0.000     2.849438    2.946171
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------France---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.30
#                                                   Prob > F        =     0.5834
#                                                   R-squared       =     0.6811
#                                                   Adj R-squared   =     0.3457
#                                                   Within R-sq.    =     0.0052
#                                                   Root MSE        =     0.5577
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.1146253   .2078555    -0.55   0.583    -.5306934    .3014427
#        _cons |   4.990708   .0657297    75.93   0.000     4.859136    5.122281
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      24.53
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9939
#                                                   Adj R-squared   =     0.9875
#                                                   Within R-sq.    =     0.2972
#                                                   Root MSE        =     0.2081
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .3840383   .0775431     4.95   0.000      .228819    .5392576
#        _cons |   2.821229   .0245213   115.05   0.000     2.772145    2.870314
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      59.78
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.8088
#                                                   Adj R-squared   =     0.6077
#                                                   Within R-sq.    =     0.5076
#                                                   Root MSE        =     0.3070
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.8845828   .1144049    -7.73   0.000    -1.113589   -.6555764
#        _cons |   4.510564    .036178   124.68   0.000     4.438146    4.582982
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
# ...
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      47.72
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9266
#                                                   Adj R-squared   =     0.8495
#                                                   Within R-sq.    =     0.4514
#                                                   Root MSE        =     0.4883
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -1.25729   .1819965    -6.91   0.000    -1.621596   -.8929848
#        _cons |   3.832578   .0575523    66.59   0.000     3.717374    3.947781
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# ------------------------Viet_Nam---------------------------------
# C:\shares_TARIFF_project\comtrade_new\DID_country
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       8.95
#                                                   Prob > F        =     0.0041
#                                                   R-squared       =     0.8315
#                                                   Adj R-squared   =     0.6542
#                                                   Within R-sq.    =     0.1337
#                                                   Root MSE        =     0.4137
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   -.461273   .1541908    -2.99   0.004    -.7699193   -.1526266
#        _cons |   4.152411   .0487594    85.16   0.000     4.054809    4.250014
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =     105.52
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9758
#                                                   Adj R-squared   =     0.9503
#                                                   Within R-sq.    =     0.6453
#                                                   Root MSE        =     1.5042
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   5.758271    .560573    10.27   0.000     4.636162     6.88038
#        _cons |   9.131787   .1772688    51.51   0.000     8.776945    9.486629
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      23.59
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9994
#                                                   Adj R-squared   =     0.9988
#                                                   Within R-sq.    =     0.2892
#                                                   Root MSE        =     0.0789
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1427469   .0293874     4.86   0.000     .0839216    .2015722
#        _cons |   2.465704   .0092931   265.33   0.000     2.447102    2.484306
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =     357.79
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9452
#                                                   Adj R-squared   =     0.8876
#                                                   Within R-sq.    =     0.8605
#                                                   Root MSE        =     0.4782
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   3.370939   .1782122    18.92   0.000     3.014209     3.72767
#        _cons |   3.211388   .0563556    56.98   0.000      3.09858    3.324196
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =    1099.69
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9947
#                                                   Adj R-squared   =     0.9891
#                                                   Within R-sq.    =     0.9499
#                                                   Root MSE        =     0.1708
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   2.111275   .0636663    33.16   0.000     1.983833    2.238717
#        _cons |   2.822317    .020133   140.18   0.000     2.782016    2.862617
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      38.56
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9918
#                                                   Adj R-squared   =     0.9831
#                                                   Within R-sq.    =     0.3993
#                                                   Root MSE        =     0.2418
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .5596805   .0901303     6.21   0.000     .3792651     .740096
#        _cons |   2.798109   .0285017    98.17   0.000     2.741056    2.855161
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =     249.45
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.8972
#                                                   Adj R-squared   =     0.7892
#                                                   Within R-sq.    =     0.8113
#                                                   Root MSE        =     0.7105
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   4.182072   .2647908    15.79   0.000     3.652035    4.712108
#        _cons |    3.77106   .0837342    45.04   0.000     3.603448    3.938672
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =      37.71
#                                                   Prob > F        =     0.0000
#                                                   R-squared       =     0.9994
#                                                   Adj R-squared   =     0.9988
#                                                   Within R-sq.    =     0.3940
#                                                   Root MSE        =     0.0791
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |   .1809456   .0294649     6.14   0.000     .1219653     .239926
#        _cons |   2.446481   .0093176   262.57   0.000      2.42783    2.465132
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout
# (6 vars, 120 obs)
#        panel variable:  time1 (strongly balanced)
#         time variable:  group, 0 to 1
#                 delta:  1 unit
# (MWFE estimator converged in 2 iterations)
#
# HDFE Linear regression                            Number of obs   =        120
# Absorbing 2 HDFE groups                           F(   1,     58) =       0.28
#                                                   Prob > F        =     0.5965
#                                                   R-squared       =     0.9990
#                                                   Adj R-squared   =     0.9979
#                                                   Within R-sq.    =     0.0049
#                                                   Root MSE        =     0.1073
#
# ------------------------------------------------------------------------------
#        value |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
# -------------+----------------------------------------------------------------
#          did |  -.0212897   .0399929    -0.53   0.597    -.1013443    .0587648
#        _cons |   2.459709   .0126469   194.49   0.000     2.434393    2.485024
# ------------------------------------------------------------------------------
#
# Absorbed degrees of freedom:
# -----------------------------------------------------+
#  Absorbed FE | Categories  - Redundant  = Num. Coefs |
# -------------+---------------------------------------|
#        time1 |        60           0          60     |
#        group |         2           1           1     |
# -----------------------------------------------------+
# dir : seeout

# %%
def get_result(result_fp):
    with open(result_fp, 'r') as fp:
        result_str = fp.read()
        match_str = re.findall(r'did\t(.*?)\n', result_str)[0]
        star_count = match_str.count('*')
        match_str = match_str.replace(',', '')
        if match_str == '-':# 若匹配到空，判定不显著
            significant = -1
            coff = -999
        else:
            if star_count == 0:
                significant = -1
                coff = float(match_str)
            else:
                coff = float(match_str.split('*')[0])
                if star_count == 1:
                    significant = 0.1
                elif star_count == 2:
                    significant = 0.05
                else:
                    significant = 0.01
    return coff, significant

result_list = []
for region in region_list:
    for sector in sector_list:
        result_fp = project_dir / 'temp-2' / f'two-events-{region}-{sector}.txt'
        coff, significant = get_result(result_fp)
        result_list.append((region, sector, coff, significant))
result_df = pd.DataFrame(result_list, columns=['region', 'sector', 'coff', 'significance'])


# # 将coff的值区间缩放至 -1,1
# data = result_df['coff']
# data_t = (data-data.mean())/(data.max()-data.min())
# result_df['coff'] = data_t
result_df.to_csv('C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-two-events.csv', header=True, index=False)
#result_df.to_csv('C:\\shares_TARIFF_project\\comtrade_new\\DID_country_cancel2018\\did-summary\\did-result-pandemic-meso-true.csv', header=True, index=False)
# result_df

# %%
result_two_events_fp = 'C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-two-events.csv'
result_two_events_df = pd.read_csv(result_two_events_fp)
result_pandemic_fp = 'C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-pandemic-meso-true.csv'
result_pandemic_df = pd.read_csv(result_pandemic_fp)
result_trade_war_fp = 'C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-trade-war-meso.csv'
result_trade_war_df = pd.read_csv(result_trade_war_fp)

import numpy as np

# 如果sign=-1（不显著），设置coff为NaN
def func(x):
    if x['significance'] == -1:
        return np.nan
    else:
        return x['coff']
result_two_events_df['coff'] = result_two_events_df.apply(func, axis=1)
result_pandemic_df['coff'] = result_pandemic_df.apply(func, axis=1)
result_trade_war_df['coff'] = result_trade_war_df.apply(func, axis=1)

merge_df = pd.merge(result_two_events_df,result_pandemic_df,  
         left_on=['region', 'sector'], 
         right_on=['region', 'sector'], 
         how='inner') \
    .rename(columns={'coff_x': 'coff_two_events', 
                     'coff_y': 'coff_pandemic',
                     'significance_x': 'sign_two_events', 
                     'significance_y': 'sign_pandemic'})


merge_df = pd.merge(merge_df, result_trade_war_df, 
         left_on=['region', 'sector'], 
         right_on=['region', 'sector'], 
         how='inner') \
    .rename(columns={'coff': 'coff_trade_war', 
                     'significance': 'sign_trade_war'})





# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# data = merge_df['coff_tradewar'].tolist()
# data_t = scaler.fit_transform(np.array(data).reshape(-1,1)).reshape(1,-1).tolist()[0]
# merge_df['coff_tradewar'] = data_t


# data = merge_df['coff_pandemic'].tolist()
# data_t = scaler.fit_transform(np.array(data).reshape(-1,1)).reshape(1,-1).tolist()[0]
# merge_df['coff_pandemic'] = data_t

merge_df.to_csv('C:\shares_TARIFF_project\comtrade_new\DID_country\did-result-merge-meso.csv', header=True, index=False)
merge_df.head()
# Out:
#    region       sector  coff_two_events  sign_two_events  coff_pandemic  \
# 0  Brazil  Agriculture          -0.4940             0.01            NaN
# 1  Brazil      Apparel          -0.0529             0.10            NaN
# 2  Brazil    Chemicals          -0.2160             0.01         -0.202
# 3  Brazil    Machinery           0.0620             0.05            NaN
# 4  Brazil    Materials              NaN            -1.00            NaN
#
#    sign_pandemic  coff_trade_war  sign_trade_war
# 0          -1.00         -0.3860            0.05
# 1          -1.00         -0.0664            0.05
# 2           0.01             NaN           -1.00
# 3          -1.00             NaN           -1.00
# 4          -1.00             NaN           -1.00

# %%
for coff_str in ['coff_two_events', 'coff_pandemic','coff_trade_war']:
    pivot_df = merge_df[['region', 'sector', coff_str]].set_index('region') \
        .pivot(columns='sector', values=coff_str)
    pivot_df.to_csv(f'C:\shares_TARIFF_project\comtrade_new\DID_country\pivot-{coff_str}-meso.csv', header=True, index=True)
